# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from imblearn.over_sampling import SMOTE

# Set LOKY_MAX_CPU_COUNT to avoid joblib warnings
os.environ["LOKY_MAX_CPU_COUNT"] = "4"  # Adjust this to match your physical core count

# Load the dataset
file_path = "OriginalDataset.csv"
df = pd.read_csv(file_path)

# Check for missing values and fill them with column means if necessary
if df.isnull().sum().sum() > 0:
    print("Warning: Missing values detected! Filling them with column means.")
    df.fillna(df.mean(numeric_only=True), inplace=True)

# Drop the 'Id' column if it exists
if 'Id' in df.columns:
    df = df.drop(columns=['Id'])

# Print initial unique career count
print(f"Unique career labels BEFORE filtering: {df['Career'].nunique()}")

# Filter out careers with very few samples
min_samples = 2  # Keep careers with at least 2 samples
career_counts = df['Career'].value_counts()
valid_careers = career_counts[career_counts >= min_samples].index
df = df[df['Career'].isin(valid_careers)]

# Print unique career count after filtering
print(f"Unique career labels AFTER filtering: {df['Career'].nunique()}")

# Ensure dataset is not empty
if df.empty:
    raise ValueError("Filtered dataset is empty. Reduce `min_samples` threshold.")

# Separate features and target variable
X = df.drop(columns=['Career'])  # Features
y = df['Career']  # Target

# Encode the target labels
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)  # Convert career names to numerical labels

# Check the number of unique classes
num_classes = len(np.unique(y_encoded))
print(f"Number of unique career labels after encoding: {num_classes}")

# Apply SMOTE only if conditions allow
if num_classes > 1 and min(career_counts) >= 2:
    print("Applying SMOTE with k_neighbors=1 to avoid errors...")
    smote = SMOTE(k_neighbors=1, random_state=42)
    X_resampled, y_resampled = smote.fit_resample(X, y_encoded)
else:
    print("Skipping SMOTE due to low samples. Using original dataset.")
    X_resampled, y_resampled = X, y_encoded  # Use the original dataset

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(
    X_resampled, y_resampled, test_size=0.2, random_state=42
)

# Train the Random Forest Classifier with optimized parameters
rf_model = RandomForestClassifier(
    n_estimators=200,  # More trees for better performance
    max_depth=10,  # Limit depth to prevent overfitting
    class_weight="balanced",  # Handle class imbalance
    random_state=42,
    n_jobs=-1  # Use all available logical cores
)
rf_model.fit(X_train, y_train)

# Make predictions
y_pred = rf_model.predict(X_test)

# Evaluate performance
accuracy = accuracy_score(y_test, y_pred)
print(f"Model Accuracy: {accuracy:.2f}")

# Decode predictions back to original labels
y_test_labels = label_encoder.inverse_transform(y_test)
y_pred_labels = label_encoder.inverse_transform(y_pred)

# Print classification report with zero_division=1 to avoid warnings
print("\nClassification Report:")
print(classification_report(y_test_labels, y_pred_labels, labels=label_encoder.classes_, zero_division=1))
# Out:
# Unique career labels BEFORE filtering: 104
# Unique career labels AFTER filtering: 104
# Number of unique career labels after encoding: 104
# Applying SMOTE with k_neighbors=1 to avoid errors...
# Model Accuracy: 0.89
#
# Classification Report:
#                                        precision    recall  f1-score   support
#
#                            Accountant       1.00      1.00      1.00         2
#                Administrative Officer       1.00      1.00      1.00         0
#                 Advertising Executive       1.00      1.00      1.00         1
#                    Aerospace Engineer       1.00      1.00      1.00         0
#                Air Traffic Controller       1.00      1.00      1.00         1
#                         Airline Pilot       1.00      1.00      1.00         0
#                             Architect       1.00      1.00      1.00         2
#                                Artist       1.00      1.00      1.00         0
#                            Astronomer       1.00      1.00      1.00         1
#                             Biologist       1.00      1.00      1.00         0
#                   Biomedical Engineer       1.00      1.00      1.00         0
#                 Biomedical Researcher       1.00      1.00      1.00         1
#                       Biotechnologist       1.00      1.00      1.00         0
#                                  Chef       1.00      1.00      1.00         2
#                          Chiropractor       1.00      1.00      1.00         1
#                        Civil Engineer       1.00      1.00      1.00         0
#                 Construction Engineer       1.00      1.00      1.00         0
# Customs and Border Protection Officer       1.00      0.00      0.00         1
#                          Data Analyst       1.00      1.00      1.00         1
#                Database Administrator       1.00      1.00      1.00         2
#                      Database Analyst       0.00      1.00      0.00         0
#                      Dental Hygienist       1.00      1.00      1.00         0
#                              Diplomat       1.00      1.00      1.00         0
#                   Electrical Engineer       1.00      1.00      1.00         1
#           Electronics Design Engineer       1.00      1.00      1.00         2
#             Elementary School Teacher       1.00      1.00      1.00         1
#                Environmental Engineer       1.00      1.00      1.00         1
#               Environmental Scientist       1.00      1.00      1.00         1
#                    Event Photographer       1.00      1.00      1.00         0
#                         Event Planner       1.00      1.00      1.00         3
#                      Fashion Designer       1.00      1.00      1.00         2
#                       Fashion Stylist       1.00      1.00      1.00         0
#                         Film Director       1.00      1.00      1.00         0
#                     Financial Advisor       1.00      1.00      1.00         2
#                     Financial Analyst       1.00      1.00      1.00         2
#                     Financial Auditor       1.00      1.00      1.00         0
#                     Financial Planner       1.00      1.00      1.00         1
#               Foreign Service Officer       1.00      1.00      1.00         0
#                 Forensic Psychologist       1.00      1.00      1.00         0
#                    Forensic Scientist       1.00      1.00      1.00         1
#                   Forestry Technician       1.00      1.00      1.00         1
#                        Game Developer       1.00      1.00      1.00         1
#                     Genetic Counselor       1.00      0.00      0.00         1
#                             Geologist       1.00      1.00      1.00         2
#                      Graphic Designer       1.00      1.00      1.00         0
#                          HR Recruiter       1.00      1.00      1.00         2
#               Human Resources Manager       1.00      1.00      1.00         0
#                   Human Rights Lawyer       1.00      1.00      1.00         2
#                    IT Project Manager       1.00      1.00      1.00         0
#                 IT Support Specialist       1.00      1.00      1.00         0
#                   Industrial Engineer       1.00      1.00      1.00         1
#                 Insurance Underwriter       1.00      0.00      0.00         1
#                     Interior Designer       1.00      1.00      1.00         1
#                     Investment Banker       1.00      1.00      1.00         2
#                            Journalist       1.00      1.00      1.00         1
#                                Lawyer       1.00      1.00      1.00         1
#                      Marine Biologist       1.00      1.00      1.00         1
#               Market Research Analyst       1.00      1.00      1.00         1
#                     Market Researcher       1.00      1.00      1.00         1
#                     Marketing Analyst       1.00      1.00      1.00         1
#                 Marketing Coordinator       1.00      1.00      1.00         1
#                  Marketing Copywriter       1.00      1.00      1.00         0
#                     Marketing Manager       1.00      1.00      1.00         0
#                    Marriage Counselor       1.00      1.00      1.00         0
#                   Mechanical Designer       1.00      1.00      1.00         0
#                   Mechanical Engineer       1.00      1.00      1.00         0
#                              Musician       1.00      1.00      1.00         1
#                                 Nurse       1.00      1.00      1.00         0
#                Occupational Therapist       1.00      1.00      1.00         0
#                       Pediatric Nurse       1.00      0.00      0.00         2
#                          Pediatrician       1.00      1.00      1.00         0
#                            Pharmacist       1.00      1.00      1.00         0
#                    Physical Therapist       0.67      1.00      0.80         2
#                             Physician       1.00      1.00      1.00         0
#                      Police Detective       1.00      1.00      1.00         1
#                        Police Officer       0.50      1.00      0.67         1
#                       Product Manager       1.00      1.00      1.00         1
#                          Psychologist       1.00      1.00      1.00         1
#                 Public Health Analyst       1.00      1.00      1.00         1
#           Public Relations Specialist       1.00      1.00      1.00         2
#             Quality Control Inspector       1.00      1.00      1.00         1
#               Radiologic Technologist       1.00      1.00      1.00         0
#                     Real Estate Agent       1.00      1.00      1.00         0
#              Rehabilitation Counselor       1.00      0.00      0.00         2
#                    Research Scientist       1.00      1.00      1.00         1
#                     Robotics Engineer       1.00      1.00      1.00         1
#                           Salesperson       1.00      1.00      1.00         0
#                  Social Media Manager       1.00      1.00      1.00         1
#                         Social Worker       1.00      1.00      1.00         1
#                    Software Developer       1.00      1.00      1.00         0
#     Software Quality Assurance Tester       1.00      1.00      1.00         0
#                    Speech Pathologist       0.20      1.00      0.33         1
#                      Speech Therapist       1.00      1.00      1.00         0
#                          Sports Coach       1.00      1.00      1.00         1
#                        Tax Accountant       1.00      1.00      1.00         1
#                         Tax Collector       1.00      1.00      1.00         0
#                               Teacher       1.00      1.00      1.00         0
#                      Technical Writer       1.00      1.00      1.00         2
#                         Urban Planner       1.00      1.00      1.00         1
#                     Video Game Tester       1.00      1.00      1.00         1
#                         Web Developer       1.00      1.00      1.00         0
#                    Wildlife Biologist       1.00      0.00      0.00         2
#              Wildlife Conservationist       1.00      1.00      1.00         1
#                             Zoologist       0.50      1.00      0.67         2
#
#                              accuracy                           0.89        84
#                             macro avg       0.97      0.94      0.92        84
#                          weighted avg       0.96      0.89      0.87        84
